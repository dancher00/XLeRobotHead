# %%
from phone_server import PhoneServer

server = PhoneServer()

# %%
server.run()
# Out:
# Server started in background thread
#
# ======================================================================
# XLeRobotHead - IMU & RealSense Server
# ======================================================================
# ✓ Server started with HTTPS support!
#
# 📱 iPhone: Open Safari and go to:
#    https://10.16.116.189:8443
#
# Features available:
#   • Video Frame Streaming (external frames)
#   • iOS IMU/Orientation Data (Fused)
# ======================================================================
# Waiting for connection...
# Video stream started for 10.16.120.33

# %%
angles = server.get_angles()
print(f"Roll: {angles['roll']:.2f}°")
print(f"Pitch: {angles['pitch']:.2f}°")
print(f"Yaw: {angles['yaw']:.2f}°")
# Out:
# Roll: 2.27°
# Pitch: 5.54°
# Yaw: 9.68°
# [iOS Fused] Roll:  -25.49° | Pitch:   42.41° | Yaw:   22.72°
# Error handling request from 10.16.120.33
# Traceback (most recent call last):
#   File "/home/danya/miniconda3/envs/xlh/lib/python3.10/site-packages/aiohttp/web_protocol.py", line 510, in _handle_request
#     resp = await request_handler(request)
#   File "/home/danya/miniconda3/envs/xlh/lib/python3.10/site-packages/aiohttp/web_app.py", line 569, in _handle
#     return await handler(request)
#   File "/home/danya/XLeRobotHead/phone_server.py", line 476, in realsense_stream_handler
#     await response.write(b'--frame\r\n')
#   File "/home/danya/miniconda3/envs/xlh/lib/python3.10/site-packages/aiohttp/web_response.py", line 560, in write
#     await self._payload_writer.write(data)
#   File "/home/danya/miniconda3/envs/xlh/lib/python3.10/site-packages/aiohttp/http_writer.py", line 202, in write
#     self._write_chunked_payload(chunk)
#   File "/home/danya/miniconda3/envs/xlh/lib/python3.10/site-packages/aiohttp/http_writer.py", line 117, in _write_chunked_payload
#     self._writelines((chunk_len_pre, chunk, b"\r\n"))
#   File "/home/danya/miniconda3/envs/xlh/lib/python3.10/site-packages/aiohttp/http_writer.py", line 106, in _writelines
#     raise ClientConnectionResetError("Cannot write to closing transport")
# aiohttp.client_exceptions.ClientConnectionResetError: Cannot write to closing transport
# Error handling request from 10.16.120.33
# Traceback (most recent call last):
#   File "/home/danya/miniconda3/envs/xlh/lib/python3.10/site-packages/aiohttp/web_protocol.py", line 510, in _handle_request
#     resp = await request_handler(request)
#   File "/home/danya/miniconda3/envs/xlh/lib/python3.10/site-packages/aiohttp/web_app.py", line 569, in _handle
#     return await handler(request)
#   File "/home/danya/XLeRobotHead/phone_server.py", line 476, in realsense_stream_handler
#     await response.write(b'--frame\r\n')
#   File "/home/danya/miniconda3/envs/xlh/lib/python3.10/site-packages/aiohttp/web_response.py", line 560, in write
#     await self._payload_writer.write(data)
#   File "/home/danya/miniconda3/envs/xlh/lib/python3.10/site-packages/aiohttp/http_writer.py", line 202, in write
#     self._write_chunked_payload(chunk)
#   File "/home/danya/miniconda3/envs/xlh/lib/python3.10/site-packages/aiohttp/http_writer.py", line 117, in _write_chunked_payload
#     self._writelines((chunk_len_pre, chunk, b"\r\n"))
#   File "/home/danya/miniconda3/envs/xlh/lib/python3.10/site-packages/aiohttp/http_writer.py", line 106, in _writelines
#     raise ClientConnectionResetError("Cannot write to closing transport")
# aiohttp.client_exceptions.ClientConnectionResetError: Cannot write to closing transport
# iPhone disconnected

# %%
import time

for i in range(10):
    angles = server.get_angles()
    print(f"[{i+1}] Roll: {angles['roll']:.2f}°, Pitch: {angles['pitch']:.2f}°, Yaw: {angles['yaw']:.2f}°")
    time.sleep(0.5)
# Out:
# [1] Roll: -1.19°, Pitch: 1.56°, Yaw: 353.48°
# [iOS Fused] Roll:   -1.20° | Pitch:    1.55° | Yaw:  353.50°[2] Roll: -1.20°, Pitch: 1.55°, Yaw: 353.50°
# [iOS Fused] Roll:   -1.20° | Pitch:    1.55° | Yaw:  353.50°[3] Roll: -1.20°, Pitch: 1.55°, Yaw: 353.50°
# [iOS Fused] Roll:   -1.11° | Pitch:    1.46° | Yaw:  353.51°[4] Roll: -1.11°, Pitch: 1.46°, Yaw: 353.51°
# [iOS Fused] Roll:  -28.59° | Pitch:    7.34° | Yaw:  354.73°[5] Roll: -28.59°, Pitch: 7.34°, Yaw: 354.73°
# [iOS Fused] Roll:   53.29° | Pitch:   31.54° | Yaw:  342.51°[6] Roll: 53.29°, Pitch: 31.54°, Yaw: 342.51°
# [iOS Fused] Roll:  -24.64° | Pitch:   10.92° | Yaw:    7.27°[7] Roll: -24.64°, Pitch: 10.92°, Yaw: 7.27°
# [iOS Fused] Roll:   68.96° | Pitch:   26.83° | Yaw:  341.87°[8] Roll: 68.96°, Pitch: 26.83°, Yaw: 341.87°
# [iOS Fused] Roll:   -9.45° | Pitch:    7.92° | Yaw:  347.77°[9] Roll: -9.45°, Pitch: 7.92°, Yaw: 347.77°
# [iOS Fused] Roll:  -10.93° | Pitch:    5.29° | Yaw:  351.44°[10] Roll: -10.93°, Pitch: 5.29°, Yaw: 351.44°
# [iOS Fused] Roll:  -10.67° | Pitch:    3.07° | Yaw:  352.04°
# [iOS Fused] Roll:   -1.08° | Pitch:    1.66° | Yaw:  352.25°
# Error handling request from 10.16.120.33
# Traceback (most recent call last):
#   File "/home/danya/miniconda3/envs/xlh/lib/python3.10/site-packages/aiohttp/web_protocol.py", line 510, in _handle_request
#     resp = await request_handler(request)
#   File "/home/danya/miniconda3/envs/xlh/lib/python3.10/site-packages/aiohttp/web_app.py", line 569, in _handle
#     return await handler(request)
#   File "/home/danya/XLeRobotHead/phone_server.py", line 476, in realsense_stream_handler
#     await response.write(b'--frame\r\n')
#   File "/home/danya/miniconda3/envs/xlh/lib/python3.10/site-packages/aiohttp/web_response.py", line 560, in write
#     await self._payload_writer.write(data)
#   File "/home/danya/miniconda3/envs/xlh/lib/python3.10/site-packages/aiohttp/http_writer.py", line 202, in write
#     self._write_chunked_payload(chunk)
#   File "/home/danya/miniconda3/envs/xlh/lib/python3.10/site-packages/aiohttp/http_writer.py", line 117, in _write_chunked_payload
#     self._writelines((chunk_len_pre, chunk, b"\r\n"))
#   File "/home/danya/miniconda3/envs/xlh/lib/python3.10/site-packages/aiohttp/http_writer.py", line 106, in _writelines
#     raise ClientConnectionResetError("Cannot write to closing transport")
# aiohttp.client_exceptions.ClientConnectionResetError: Cannot write to closing transport
# Error handling request from 10.16.120.33
# Traceback (most recent call last):
#   File "/home/danya/miniconda3/envs/xlh/lib/python3.10/site-packages/aiohttp/web_protocol.py", line 510, in _handle_request
#     resp = await request_handler(request)
#   File "/home/danya/miniconda3/envs/xlh/lib/python3.10/site-packages/aiohttp/web_app.py", line 569, in _handle
#     return await handler(request)
#   File "/home/danya/XLeRobotHead/phone_server.py", line 476, in realsense_stream_handler
#     await response.write(b'--frame\r\n')
#   File "/home/danya/miniconda3/envs/xlh/lib/python3.10/site-packages/aiohttp/web_response.py", line 560, in write
#     await self._payload_writer.write(data)
#   File "/home/danya/miniconda3/envs/xlh/lib/python3.10/site-packages/aiohttp/http_writer.py", line 202, in write
#     self._write_chunked_payload(chunk)
#   File "/home/danya/miniconda3/envs/xlh/lib/python3.10/site-packages/aiohttp/http_writer.py", line 117, in _write_chunked_payload
#     self._writelines((chunk_len_pre, chunk, b"\r\n"))
#   File "/home/danya/miniconda3/envs/xlh/lib/python3.10/site-packages/aiohttp/http_writer.py", line 106, in _writelines
#     raise ClientConnectionResetError("Cannot write to closing transport")
# aiohttp.client_exceptions.ClientConnectionResetError: Cannot write to closing transport
# iPhone disconnected

# %%
server.stop()
# Out:
# Server stopped
